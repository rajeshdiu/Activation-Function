# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Activation_Function import Activation_Function  as AF
# from keras.datasets import *

# %%
def visualization():
    nameOfActivationFunction=["identity","binary_step","tanh","sigmoid","softmax","ReLu","LeakyReLu","arcTan"]
    
    trackingDictionary={
        0:"plt.plot(x,AF.identity(x))",
        1:"plt.plot(x,AF.binary_step(x))",
        2:"plt.plot(x,AF.tanh(x))",
        3:"plt.plot(x,AF.sigmoid(x))",
        4:"plt.plot(x,AF.softmax(x))",
        5:"plt.plot(x,AF.ReLu(x))",
        6:"plt.plot(x,AF.LeakyReLu(x))",
        7:"plt.plot(x,AF.arcTan(x))",
    }

    for i in range(8):
        x=np.linspace(-10,10)
        exec(trackingDictionary[i])
        plt.axis("tight")
        plt.title("Creating a Visalization for "+nameOfActivationFunction[i]+" Function")
        plt.tight_layout()
        plt.show()

# %%
visualization()
